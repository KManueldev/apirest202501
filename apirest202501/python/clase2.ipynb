# %% [markdown]
# https://jarroba.com/python-mongodb-driver-pymongo-con-ejemplos/

# %%
#pip install pymongo
# Out:
# Requirement already satisfied: pymongo in c:\users\kevin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (4.11.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\kevin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pymongo) (2.7.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\kevin\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from pymongo import MongoClient

# %%
class Futbolista:

    def __init__(self, nombre: str, apellidos: str, edad: int, internacional: bool):
        self.nombre = nombre
        self.apellidos = apellidos
        self.edad = edad
        self.internacional = internacional

    def toDBCollection(self):
        return {
            "nombre": self.nombre,
            "apellidos": self.apellidos,
            "edad": self.edad,
            "internacional": self.internacional
        }

    def __str__(self):
        return f"Nombre: {self.nombre} - Apellidos: {self.apellidos} - Edad: {self.edad} - Internacional: {self.internacional}"

# %%
# Creo una lista de objetos futbolista a insertar en la BD
futbolistas = [
    Futbolista('Iker','Casillas',33, True),
    Futbolista('Carles','Puyol',36,False),
    Futbolista('Sergio','Ramos',28,True),
    Futbolista('Andrés','Iniesta',30,True),
    Futbolista('Fernando','Torres',30,True),
    Futbolista('Leo','Baptistao',22,False),
    Futbolista('Juan','Baptistao',22,False),
    Futbolista('diego','Baptistao',22,False),
    Futbolista('camilo','Baptistao',22,False),
    Futbolista('Espin','Baptistao',22,False),
    Futbolista('Diego','Baptistao',22,False),
]

# %%
# PASO 1: Conexión al Server de MongoDB Pasandole el host y el puerto

client = MongoClient("mongodb+srv://KevinMango:Mango321@cluster0.hdmf1.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
#client = MongoClient("mongodb+srv://cgiohidalgo:holamundo123@cluster0.gnjw3xg.mongodb.net/?retryWrites=true&w=majority")
#db = client.test

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)

db = client.prueba

collection = db.Futbolistas
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
# PASO 4.1: "CREATE" -> Metemos los objetos futbolista (o documentos en Mongo) en la coleccion Futbolista
futbolistas_insertados = []
for futbolista in futbolistas:
    resultado = collection.insert_one(futbolista.toDBCollection())
    futbolistas_insertados.append(resultado.inserted_id)
#print("Futbolistas insertados: ", futbolistas_insertados)
print("Futbolistas insertados: ", futbolistas_insertados)
# Out:
# Futbolistas insertados:  [ObjectId('67e45075c9b12e1a2b86c7ec'), ObjectId('67e45075c9b12e1a2b86c7ed'), ObjectId('67e45075c9b12e1a2b86c7ee'), ObjectId('67e45075c9b12e1a2b86c7ef'), ObjectId('67e45075c9b12e1a2b86c7f0'), ObjectId('67e45075c9b12e1a2b86c7f1'), ObjectId('67e45075c9b12e1a2b86c7f2'), ObjectId('67e45075c9b12e1a2b86c7f3'), ObjectId('67e45075c9b12e1a2b86c7f4'), ObjectId('67e45075c9b12e1a2b86c7f5'), ObjectId('67e45076c9b12e1a2b86c7f6')]

# %%
# Actualizar 
resultado  = collection.update_one({"nombre":"Andrés"}, {"$set": {"nombre":"Andrés Juan"}})

print("Documento actualizado: ", resultado.modified_count)

# Futbolista('Sergio','Ramos',28,True),
#    Futbolista('Andrés','Iniesta',30,True),

#resultado  = collection.findByIdAndUpdate({'660ad4ebf338955d1a88f67f'}, {"$set": {"nombre":"Andrés Pedro"}})

#print("Documento actualizado: ", resultado.modified_count)



#Eliminar
# Out:
# Documento actualizado:  1

# %%
#SELECT * FROM Futbolistas
resultado2 = collection.find()

for fut in resultado2:
    print(fut)

#SELECT * FROM Futbolistas
#WHERE nombre = 'Andrés Juan'
resultado1 = collection.find({"nombre":'Andrés Juan'})

for fut in resultado1:
    print(fut)



{"nombre":'Andrés Juan'}
# Out:
# {'_id': ObjectId('67db22c75c1b08503dd0bcae'), 'nombre': 'Iker', 'apellidos': 'Casillas', 'edad': 33, 'internacional': 0}
# {'_id': ObjectId('67db22c85c1b08503dd0bcaf'), 'nombre': 'Carles', 'apellidos': 'Puyol', 'edad': 36, 'internacional': 1}
# {'_id': ObjectId('67db22c85c1b08503dd0bcb0'), 'nombre': 'Sergio', 'apellidos': 'Ramos', 'edad': 28, 'internacional': True}
# {'_id': ObjectId('67db22c85c1b08503dd0bcb1'), 'nombre': 'Andrés Juan', 'apellidos': 'Iniesta', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('67db22c95c1b08503dd0bcb2'), 'nombre': 'Fernando', 'apellidos': 'Torres', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('67db22c95c1b08503dd0bcb3'), 'nombre': 'Leo', 'apellidos': 'Baptistao', 'edad': 22, 'internacional': False}
# {'_id': ObjectId('67e44fef7a00474a92148ee7'), 'nombre': 'Iker', 'apellidos': 'Casillas', 'edad': 33, 'internacional': 0}
# {'_id': ObjectId('67e44ff07a00474a92148ee8'), 'nombre': 'Carles', 'apellidos': 'Puyol', 'edad': 36, 'internacional': 1}
# {'_id': ObjectId('67e44ff07a00474a92148ee9'), 'nombre': 'Sergio', 'apellidos': 'Ramos', 'edad': 28, 'internacional': True}
# {'_id': ObjectId('67e44ff07a00474a92148eea'), 'nombre': 'Andrés', 'apellidos': 'Iniesta', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('67e44ff07a00474a92148eeb'), 'nombre': 'Fernando', 'apellidos': 'Torres', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('67e44ff07a00474a92148eec'), 'nombre': 'Leo', 'apellidos': 'Baptistao', 'edad': 22, 'internacional': False}
# {'_id': ObjectId('67e45075c9b12e1a2b86c7ec'), 'nombre': 'Iker', 'apellidos': 'Casillas', 'edad': 33, 'internacional': True}
# {'_id': ObjectId('67e45075c9b12e1a2b86c7ed'), 'nombre': 'Carles', 'apellidos': 'Puyol', 'edad': 36, 'internacional': False}
# {'_id': ObjectId('67e45075c9b12e1a2b86c7ee'), 'nombre': 'Sergio', 'apellidos': 'Ramos', 'edad': 28, 'internacional': True}
# {'_id': ObjectId('67e45075c9b12e1a2b86c7ef'), 'nombre': 'Andrés', 'apellidos': 'Iniesta', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('67e45075c9b12e1a2b86c7f0'), 'nombre': 'Fernando', 'apellidos': 'Torres', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('67e45075c9b12e1a2b86c7f1'), 'nombre': 'Leo', 'apellidos': 'Baptistao', 'edad': 22, 'internacional': False}
# {'_id': ObjectId('67e45075c9b12e1a2b86c7f2'), 'nombre': 'Juan', 'apellidos': 'Baptistao', 'edad': 22, 'internacional': False}
# {'_id': ObjectId('67e45075c9b12e1a2b86c7f3'), 'nombre': 'diego', 'apellidos': 'Baptistao', 'edad': 22, 'internacional': False}
# {'_id': ObjectId('67e45075c9b12e1a2b86c7f4'), 'nombre': 'camilo', 'apellidos': 'Baptistao', 'edad': 22, 'internacional': False}
# {'_id': ObjectId('67e45075c9b12e1a2b86c7f5'), 'nombre': 'Espin', 'apellidos': 'Baptistao', 'edad': 22, 'internacional': False}
# {'_id': ObjectId('67e45076c9b12e1a2b86c7f6'), 'nombre': 'Diego', 'apellidos': 'Baptistao', 'edad': 22, 'internacional': False}
# {'_id': ObjectId('67db22c85c1b08503dd0bcb1'), 'nombre': 'Andrés Juan', 'apellidos': 'Iniesta', 'edad': 30, 'internacional': True}
# {'nombre': 'Andrés Juan'}

# %%
resultado = collection.delete_one({"nombre":'Andrés Juan'})

if resultado.deleted_count == 1:
    print("Se elimino el documento")
else:
    print("No se elimino el documento")

resultado1 = collection.find({"nombre":'Andrés Juan'})

for fut in resultado1:
    print(fut)
# Out:
# Se elimino el documento

# %%
resultado  = collection.update_many({"nombre": {"$in": ["Iker", "Carles"]}}, {"$set": {"edad": 65}})

print (f"se actualziaron {resultado.modified_count} documentos")
# Out:
# se actualziaron 6 documentos

# %%
resultado = collection.delete_many({"apellidos": {"$regex":"^B"}})


if resultado.deleted_count > 0:
    print("Se eliminaron",resultado.deleted_count, "documentos")
else:
    print("No se eliminaron Documentos...")
# Out:
# Se eliminaron 8 documentos

# %%
print(futbolistas[0])
# Out:
# Nombre: Iker - Apellidos: Casillas - Edad: 33 - Internacional: True

# %%
import matplotlib.pyplot as plt

futbolistas2 = collection.find()

futbolistas_consultados = []
for fut in futbolistas2:
    #print(fut['nombre'])
    unFutbolista = Futbolista(fut['nombre'],fut['apellidos'],fut['edad'],fut['internacional'])
    futbolistas_consultados.append(unFutbolista)

#print(futbolistas_consultados)

# Lista de nombres y edades de los futbolistas
nombres = [futbolista.nombre for futbolista in futbolistas_consultados]
edades = [futbolista.edad for futbolista in futbolistas_consultados]

# Crear un gráfico de barras
plt.bar(nombres, edades)

# Agregar etiquetas a los ejes
plt.xlabel('Nombre')
plt.ylabel('Edad')

# Mostrar el gráfico
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Query the collection to get the ages of all the players
ages = collection.distinct('edad')

# Count the number of players for each age
counts = [collection.count_documents({'edad': age}) for age in ages]

# Create a bar chart using Matplotlib
plt.bar(ages, counts)
plt.title('Number of players by age')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
import matplotlib.pyplot as plt

# Count the number of international and non-international players
num_international = collection.count_documents({'internacional': True})
num_non_international = collection.count_documents({'internacional': False})

print(num_international,num_non_international )

# Create a pie chart using Matplotlib
labels = ['International', 'Non-International']
sizes = [num_international, num_non_international]
explode = (0.1, 0)

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', startangle=90)
ax1.axis('equal')

plt.title('Percentage of international and non-international players')
plt.show()
# Out:
# 9 1

# %%
import matplotlib.pyplot as plt

# Get the ages of all players in the collection
ages = [futbolista["edad"] for futbolista in collection.find()]



# Create a histogram using Matplotlib
plt.hist(ages, bins=10, color='green')

plt.title('Distribution of player ages')
plt.xlabel('Age')
plt.ylabel('Frequency')

plt.show()

# %%
#pip install pandas

# %%
import pandas as pd

# Create a cursor to iterate over the collection
resultado = collection.find()

# Create a list to store the documents
documentos = []

# Iterate over the cursor and append the documents to the list
for document in resultado:
    documentos.append(document)

# Create a DataFrame from the list of documents
df = pd.DataFrame(documentos)

# Print the DataFrame
print(df)
# Out:
#                          _id    nombre apellidos  edad internacional
# 0   67db22c75c1b08503dd0bcae      Iker  Casillas    65             0
# 1   67db22c85c1b08503dd0bcaf    Carles     Puyol    65             1
# 2   67db22c85c1b08503dd0bcb0    Sergio     Ramos    28          True
# 3   67db22c95c1b08503dd0bcb2  Fernando    Torres    30          True
# 4   67e44fef7a00474a92148ee7      Iker  Casillas    65             0
# 5   67e44ff07a00474a92148ee8    Carles     Puyol    65             1
# 6   67e44ff07a00474a92148ee9    Sergio     Ramos    28          True
# 7   67e44ff07a00474a92148eea    Andrés   Iniesta    30          True
# 8   67e44ff07a00474a92148eeb  Fernando    Torres    30          True
# 9   67e45075c9b12e1a2b86c7ec      Iker  Casillas    65          True
# 10  67e45075c9b12e1a2b86c7ed    Carles     Puyol    65         False
# 11  67e45075c9b12e1a2b86c7ee    Sergio     Ramos    28          True
# 12  67e45075c9b12e1a2b86c7ef    Andrés   Iniesta    30          True
# 13  67e45075c9b12e1a2b86c7f0  Fernando    Torres    30          True

# %%
df.describe()
# Out:
#             edad
# count  14.000000
# mean   44.571429
# std    18.375210
# min    28.000000
# 25%    30.000000
# 50%    30.000000
# 75%    65.000000
# max    65.000000

# %%
df1 = df.drop_duplicates()
print(df1)
# Out:
#                          _id    nombre apellidos  edad internacional
# 0   67db22c75c1b08503dd0bcae      Iker  Casillas    65             0
# 1   67db22c85c1b08503dd0bcaf    Carles     Puyol    65             1
# 2   67db22c85c1b08503dd0bcb0    Sergio     Ramos    28          True
# 3   67db22c95c1b08503dd0bcb2  Fernando    Torres    30          True
# 4   67e44fef7a00474a92148ee7      Iker  Casillas    65             0
# 5   67e44ff07a00474a92148ee8    Carles     Puyol    65             1
# 6   67e44ff07a00474a92148ee9    Sergio     Ramos    28          True
# 7   67e44ff07a00474a92148eea    Andrés   Iniesta    30          True
# 8   67e44ff07a00474a92148eeb  Fernando    Torres    30          True
# 9   67e45075c9b12e1a2b86c7ec      Iker  Casillas    65          True
# 10  67e45075c9b12e1a2b86c7ed    Carles     Puyol    65         False
# 11  67e45075c9b12e1a2b86c7ee    Sergio     Ramos    28          True
# 12  67e45075c9b12e1a2b86c7ef    Andrés   Iniesta    30          True
# 13  67e45075c9b12e1a2b86c7f0  Fernando    Torres    30          True

# %%
df2 = df.drop_duplicates(subset=['nombre'])
print(df2)
# Out:
#                         _id    nombre apellidos  edad internacional
# 0  67db22c75c1b08503dd0bcae      Iker  Casillas    65             0
# 1  67db22c85c1b08503dd0bcaf    Carles     Puyol    65             1
# 2  67db22c85c1b08503dd0bcb0    Sergio     Ramos    28          True
# 3  67db22c95c1b08503dd0bcb2  Fernando    Torres    30          True
# 7  67e44ff07a00474a92148eea    Andrés   Iniesta    30          True
